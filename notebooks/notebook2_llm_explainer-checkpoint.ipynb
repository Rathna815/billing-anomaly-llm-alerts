# %%
# LLM Alert Explainer
**Goal:** For each detected anomaly, generate a human-readable alert summary
that a billing operations team can act on immediately — no data science knowledge required.
# Out:
#   Cell In[1], line 3
#     that a billing operations team can act on immediately — no data science knowledge required.
#                                                           ^
# SyntaxError: invalid character '—' (U+2014)

# %%
import pandas as pd
import numpy as np
import sqlite3
import os
import matplotlib.pyplot as plt
import seaborn as sns
from groq import Groq

api_key = "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"
client  = Groq(api_key=api_key)

# Quick test
test = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": "Say OK in one word."}],
    max_tokens=5
)
print("Groq connected:", test.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 13
#      10 client  = Groq(api_key=api_key)
#      12 # Quick test
# ---> 13 test = client.chat.completions.create(
#      14     model="llama-3.1-8b-instant",
#      15     messages=[{"role": "user", "content": "Say OK in one word."}],
#      16     max_tokens=5
#      17 )
#      18 print("Groq connected:", test.choices[0].message.content)
#
# ...
